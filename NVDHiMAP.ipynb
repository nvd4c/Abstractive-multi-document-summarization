# %%
# !nvidia-smi
# Out:
# Tue Mar  8 03:10:13 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8    28W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# %cd /content
# !git clone https://github.com/Alex-Fabbri/Multi-News
# !git clone https://github.com/nvd4c/Multi-News
# Out:
# /content
# Cloning into 'Multi-News'...
# remote: Enumerating objects: 298, done.
# remote: Counting objects: 100% (298/298), done.
# remote: Compressing objects: 100% (251/251), done.
# remote: Total 298 (delta 43), reused 297 (delta 42), pack-reused 0
# Receiving objects: 100% (298/298), 54.62 MiB | 19.58 MiB/s, done.
# Resolving deltas: 100% (43/43), done.
# Checking out files: 100% (314/314), done.

# %%
# !cp -r /content/Multi-News/code/Hi_MAP/* /content

# %% [markdown]
# # Hi MAP

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content
# !mkdir data
# !cp /content/drive/Shareddrives/Anime_Olshiro/AIdata/Multi-News_HI_MAP/datatruncated.zip /content/data
# %cd /content/data
# !unzip datatruncated.zip
# Out:
# /content
# /content/data
# Archive:  datatruncated.zip
#   inflating: val.txt.tgt.tokenized.fixed.cleaned.final.truncated.txt
#   inflating: test.txt.tgt.tokenized.fixed.cleaned.final.truncated.txt
#   inflating: val.txt.src.tokenized.fixed.cleaned.final.truncated.txt
#   inflating: test.txt.src.tokenized.fixed.cleaned.final.truncated.txt
#   inflating: train.txt.tgt.tokenized.fixed.cleaned.final.truncated.txt
#   inflating: train.txt.src.tokenized.fixed.cleaned.final.truncated.txt

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# !pip install torchtext==0.6.0
# Out:
# ...
#      |████████████████████████████████| 64 kB 2.2 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 11.2 MB/s
# ...
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.11.0
#     Uninstalling torchtext-0.11.0:
#       Successfully uninstalled torchtext-0.11.0
# ...

# %% [markdown]
# # Prepare data

# %%
# %cd /content
# !chmod +x run_prep_newser.sh
# Out:
# /content

# %%
# %cd /content
# !mkdir newser_sent_500
# !./run_prep_newser.sh
# Out:
# /content
# [2022-03-08 03:11:04,195 INFO] Extracting features...
# [2022-03-08 03:11:04,197 INFO]  * number of source features: 0.
# [2022-03-08 03:11:04,197 INFO]  * number of target features: 0.
# [2022-03-08 03:11:04,197 INFO] Building `Fields` object...
# [2022-03-08 03:11:04,197 INFO] Building & saving training data...
# [2022-03-08 03:11:04,197 INFO]  * divide corpus into shards and build dataset separately (shard_size = 10000000 bytes).
# [2022-03-08 03:11:16,483 INFO]  * saving train data shard to ./newser_sent_500/newser_sents.train.1.pt.
# [2022-03-08 03:11:33,777 INFO]  * saving train data shard to ./newser_sent_500/newser_sents.train.2.pt.
# [2022-03-08 03:11:51,191 INFO]  * saving train data shard to ./newser_sent_500/newser_sents.train.3.pt.
# [2022-03-08 03:12:07,846 INFO]  * saving train data shard to ./newser_sent_500/newser_sents.train.4.pt.
# [2022-03-08 03:12:24,729 INFO]  * saving train data shard to ./newser_sent_500/newser_sents.train.5.pt.
# ...

# %%
# !git clone --branch 0.2.1  https://github.com/OpenNMT/OpenNMT-py

# %%
# %cd OpenNMT-py
# !pip install . -v 
# %cd /content

# %% [markdown]
# # Training

# %%
# %cd /content
# !chmod +x run_train_newser.sh

# %%
# %cd /content
# !./run_train_newser.sh
# Out:
# /content
# Traceback (most recent call last):
#   File "train.py", line 126, in <module>
#     main(opt)
#   File "train.py", line 57, in main
#     single_main(opt, 0)
#   File "/content/onmt/train_single.py", line 100, in main
#     fields = _load_fields(first_dataset, data_type, opt, checkpoint)
#   File "/content/onmt/inputters/inputter.py", line 589, in _load_fields
#     torch.load(opt.data + '.vocab.pt'), data_type)
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 594, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 230, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 211, in __init__
#     super(_open_file, self).__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: 'newser_sent_500/newser_sents.vocab.pt'

# %%
# %cd /content
# !mkdir model_newser_atten
# !mkdir output_newser
# !mkdir Newser_data_test_src
# %cd /content/model_newser_atten
# !gdown --id 12sRpbapqa8CfpsfiKa9GtcC9iTaJsPon
# !cp /content/drive/Shareddrives/Anime_Olshiro/AI_checkpoint/Multi-News/Hi_MAP/ph2/himap_step_17000.pt .
# Out:
# /content
# mkdir: cannot create directory ‘model_newser_atten’: File exists
# mkdir: cannot create directory ‘output_newser’: File exists
# /content/model_newser_atten

# %% [markdown]
# # Inference

# %%
# !git clone https://github.com/PaleNeutron/Multi-News nes
# !cp -r /content/nes/code/Hi_MAP/* /content
# Out:
# Cloning into 'nes'...
# remote: Enumerating objects: 448, done.
# remote: Total 448 (delta 0), reused 0 (delta 0), pack-reused 448
# Receiving objects: 100% (448/448), 56.65 MiB | 25.77 MiB/s, done.
# Resolving deltas: 100% (173/173), done.
# Checking out files: 100% (252/252), done.
# cp: cannot stat '/content/nes/code/Hi_MAP/*': No such file or directory

# %%
# %cd /content
# !chmod +x run_inference_newser.sh
# Out:
# /content

# %%
# %cd /content
# !mkdir output_newser
# !rm -rf output_newser/*
# !./run_inference_newser.sh
# Out:
# /content
# mkdir: cannot create directory ‘output_newser’: File exists
# Namespace(alpha=0.9, attn_debug=False, batch_size=8, beam_size=4, beta=5.0, block_ngram_repeat=3, coverage_penalty='summary', data_type='text', dump_beam='', dynamic_dict=False, fast=False, gpu=-1, ignore_when_blocking=['story_separator_special_tag'], image_channel_size=3, length_penalty='wu', log_file='', max_length=300, max_sent_length=None, min_length=200, models=['/content/model_newser_atten/himap_step_10500.pt'], n_best=1, output='output_newser/Feb17__step_20000_full.output', replace_unk=False, report_bleu=False, report_rouge=False, sample_rate=16000, share_vocab=False, src='/content/data/test.txt.src.tokenized.fixed.cleaned.final.truncated.txt', src_dir='', stepwise_penalty=True, tgt=None, verbose=True, window='hamming', window_size=0.02, window_stride=0.01)
# Traceback (most recent call last):
#   File "translate.py", line 38, in <module>
#     main(opt)
#   File "translate.py", line 19, in main
# ...
